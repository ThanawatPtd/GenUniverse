# %%
# Import required libraries  
import os  
import json  
from openai import AzureOpenAI, DefaultHttpxClient
from dotenv import load_dotenv, find_dotenv
from azure.core.credentials import AzureKeyCredential  
from azure.search.documents import SearchClient  
from azure.search.documents.indexes import SearchIndexClient  
from azure.search.documents.indexes.models import (  
    SearchIndex,  
    SearchField,  
    SearchFieldDataType,  
    SimpleField,  
    SearchableField,  
    SearchIndex,  
    SemanticConfiguration,  
    PrioritizedFields,  
    SemanticField,  
    SearchField,  
    SemanticSettings,  
    VectorSearch,
    HnswVectorSearchAlgorithmConfiguration,
)
from pathlib import Path

# %%
# Configure environment variables  
load_dotenv(find_dotenv('credential.env'), override=True)

# Azure AI Search
service_endpoint = os.environ['AZURE_AI_SEARCH_ENDPOINT']
key = os.environ['AZURE_AI_SEARCH_KEY']
index_name = os.environ['AZURE_AI_SEARCH_INDEX_NAME']
credential = AzureKeyCredential(key)

#Azure OpenAI
client = AzureOpenAI(
  api_key = os.environ['AZURE_OPENAI_API_KEY'],  # this is also the default, it can be omitted
  azure_endpoint = os.environ['AZURE_OPENAI_API_ENDPOINT'],
  api_version = os.environ['AZURE_OPENAI_API_VERSION'],
  http_client = DefaultHttpxClient(verify=False)
)
embedding_model = os.environ['EMBEDDING_MODEL_NAME']

# %%
# Declare useful method
def check_and_create_folder(folder_name):
    if not os.path.exists(folder_name):
        os.makedirs(folder_name)
        print(f"The folder '{folder_name}' has been created.")
    else:
        print(f"The folder '{folder_name}' already exists.")

def print_error_message(message, prefix_message='Error: '):
    print(f"\033[1;31m{prefix_message}\033[0m{message}")

def print_warning_message(message, prefix_message='Warning: '):
    print(f"\033[1;33m{prefix_message}\033[0m{message}")
    
def print_success_message(message, prefix_message='Success: '):
    print(f"\033[1;32m{prefix_message}\033[0m{message}")

# %%
def generate_embeddings(text):
    response = client.embeddings.create(input=text, model=embedding_model)
    return response.data[0].embedding

# %%
print_warning_message("Generate embeddings of chunked document", ">>>[STEP4] ")

# Set the local folder name for document intelligence output
# Check if the folder exists
check_and_create_folder("data/chunked_document_vector")

# Create embeddings on field "Content" using Azure OpenAI embedding model        
for file in Path("data/chunked_document").glob("*.json"):
    input_data = json.loads(file.read_text(encoding='utf-8'))
    content = input_data['content']
    content_embeddings = generate_embeddings(content)
    input_data['contentVector'] = content_embeddings
    output_file_path = f"data/chunked_document_vector/{file.name}"
    with open(output_file_path, "w", encoding='utf-8') as f:
        json.dump(input_data, f, ensure_ascii=False, indent=4)
    print_success_message(f'Embedding chunked document {file.name}')
# Out:
# >>>[STEP4] Generate embeddings of chunked document
# The folder 'data/chunked_document_vector' already exists.
# Success: Embedding chunked document mobil-super-moto-20w40_pdf-0.json
# Success: Embedding chunked document choosing-the-right-oil-for-your-car_pdf-0.json
# Success: Embedding chunked document mobil-1_pdf-0.json
# Success: Embedding chunked document suzuki_pdf-1.json
# Success: Embedding chunked document mobil-1-turbo-diesel-pickup-5w40_pdf-0.json
# Success: Embedding chunked document mobil-super_pdf-1.json
# Success: Embedding chunked document toyota_pdf-1.json
# Success: Embedding chunked document mobil-super-moto-scooter-gear-oil_pdf-1.json
# Success: Embedding chunked document mazda_pdf-1.json
# Success: Embedding chunked document mobil-super-moto-scooter-10w40_pdf-1.json
# Success: Embedding chunked document product-oem-bmw_pdf-1.json
# Success: Embedding chunked document subaru_pdf-1.json
# Success: Embedding chunked document recommended-for-your-car_pdf-0.json
# Success: Embedding chunked document isuzu_pdf-0.json
# Success: Embedding chunked document mobil-1-esp-0w-30_pdf-1.json
# Success: Embedding chunked document choose-the-right-engine-oil_pdf-2.json
# Success: Embedding chunked document mobil-super-friction-fighter-10w-40_pdf-1.json
# Success: Embedding chunked document mobil-super-friction-fighter-10w-40_pdf-0.json
# Success: Embedding chunked document mobil-1-esp-0w-30_pdf-0.json
# Success: Embedding chunked document isuzu_pdf-1.json
# Success: Embedding chunked document recommended-for-your-car_pdf-1.json
# Success: Embedding chunked document subaru_pdf-0.json
# Success: Embedding chunked document product-oem-bmw_pdf-0.json
# Success: Embedding chunked document mobil-super-moto-scooter-10w40_pdf-0.json
# Success: Embedding chunked document mazda_pdf-0.json
# Success: Embedding chunked document mobil-super-moto-scooter-gear-oil_pdf-0.json
# Success: Embedding chunked document mobil-super_pdf-0.json
# Success: Embedding chunked document toyota_pdf-0.json
# Success: Embedding chunked document suzuki_pdf-0.json
# Success: Embedding chunked document mobil-1-turbo-diesel-pickup-5w40_pdf-1.json
# Success: Embedding chunked document mobil-1_pdf-1.json
# Success: Embedding chunked document choosing-the-right-oil-for-your-car_pdf-1.json
# Success: Embedding chunked document tips-all-drivers-should-know_pdf-2.json
# Success: Embedding chunked document mobil-super-moto-20w40_pdf-1.json
# Success: Embedding chunked document mobil-super-all-in-one-protection-0w-20_pdf-0.json
# Success: Embedding chunked document honda_pdf-1.json
# Success: Embedding chunked document changing-motorbike-engine-oil_pdf-1.json
# Success: Embedding chunked document mobil-1-racing-4t-10w40_pdf-2.json
# Success: Embedding chunked document mobil-super-all-in-one-protection-5w-30_pdf-2.json
# Success: Embedding chunked document mobil-super-all-in-one-protection-5w-40_pdf-1.json
# Success: Embedding chunked document mobil-super-everyday-protection-20w-50_pdf-0.json
# Success: Embedding chunked document time-to-add-car-care-to-your-calendar_pdf-1.json
# Success: Embedding chunked document bike-and-scooter-products_pdf-0.json
# Success: Embedding chunked document bmw_pdf-0.json
# Success: Embedding chunked document car_pdf-1.json
# Success: Embedding chunked document where-to-buy_pdf-1.json
# Success: Embedding chunked document ford_pdf-1.json
# Success: Embedding chunked document nissan_pdf-2.json
# Success: Embedding chunked document ford_pdf-0.json
# Success: Embedding chunked document car_pdf-0.json
# Success: Embedding chunked document where-to-buy_pdf-0.json
# Success: Embedding chunked document bmw_pdf-1.json
# Success: Embedding chunked document bike-and-scooter-products_pdf-1.json
# Success: Embedding chunked document time-to-add-car-care-to-your-calendar_pdf-0.json
# Success: Embedding chunked document mobil-super-all-in-one-protection-5w-40_pdf-0.json
# Success: Embedding chunked document mobil-super-everyday-protection-20w-50_pdf-1.json
# Success: Embedding chunked document mitsubishi_pdf-2.json
# Success: Embedding chunked document mobil-super-moto_pdf-2.json
# Success: Embedding chunked document changing-motorbike-engine-oil_pdf-0.json
# Success: Embedding chunked document honda_pdf-0.json
# Success: Embedding chunked document mobil-super-all-in-one-protection-0w-20_pdf-1.json
# Success: Embedding chunked document mitsubishi_pdf-1.json
# Success: Embedding chunked document why-mobil_pdf-0.json
# Success: Embedding chunked document mobil-super-moto_pdf-1.json
# Success: Embedding chunked document mobil-1-racing-4t-10w40_pdf-0.json
# Success: Embedding chunked document mobil-super-moto-10w30_pdf-1.json
# Success: Embedding chunked document mobil-super-all-in-one-protection-0w-20_pdf-2.json
# Success: Embedding chunked document nissan_pdf-0.json
# Success: Embedding chunked document bmw_pdf-2.json
# Success: Embedding chunked document bike-and-scooter-products_pdf-2.json
# Success: Embedding chunked document mobil-super-everyday-protection-20w-50_pdf-2.json
# Success: Embedding chunked document mobil-super-all-in-one-protection-5w-30_pdf-0.json
# Success: Embedding chunked document mobil-super-all-in-one-protection-5w-30_pdf-1.json
# Success: Embedding chunked document ford_pdf-2.json
# Success: Embedding chunked document nissan_pdf-1.json
# Success: Embedding chunked document honda_pdf-2.json
# Success: Embedding chunked document changing-motorbike-engine-oil_pdf-2.json
# Success: Embedding chunked document mobil-1-racing-4t-10w40_pdf-1.json
# Success: Embedding chunked document mobil-super-moto-10w30_pdf-0.json
# Success: Embedding chunked document mobil-super-moto_pdf-0.json
# Success: Embedding chunked document why-mobil_pdf-1.json
# Success: Embedding chunked document mitsubishi_pdf-0.json
# Success: Embedding chunked document toyota_pdf-3.json
# Success: Embedding chunked document mobil-1-turbo-diesel-pickup-5w40_pdf-2.json
# Success: Embedding chunked document mobil-1_pdf-2.json
# Success: Embedding chunked document choosing-the-right-oil-for-your-car_pdf-2.json
# Success: Embedding chunked document bike-and-scooter_pdf-0.json
# Success: Embedding chunked document tips-all-drivers-should-know_pdf-1.json
# Success: Embedding chunked document mobil-super-moto-20w-50_pdf-0.json
# Success: Embedding chunked document benchmarks-to-change-motorcyle-engine-oils_pdf-0.json
# Success: Embedding chunked document choose-the-right-engine-oil_pdf-0.json
# Success: Embedding chunked document isuzu_pdf-2.json
# Success: Embedding chunked document mobil-super-moto-10w-40_pdf-0.json
# Success: Embedding chunked document mobil-super-moto-10w-40_pdf-1.json
# Success: Embedding chunked document mazda_pdf-2.json
# Success: Embedding chunked document product-oem-bmw_pdf-2.json
# Success: Embedding chunked document subaru_pdf-2.json
# Success: Embedding chunked document mobil-1-esp-0w-30_pdf-2.json
# Success: Embedding chunked document choose-the-right-engine-oil_pdf-1.json
# Success: Embedding chunked document benchmarks-to-change-motorcyle-engine-oils_pdf-1.json
# Success: Embedding chunked document mobil-super-moto-20w-50_pdf-1.json
# Success: Embedding chunked document tips-all-drivers-should-know_pdf-0.json
# Success: Embedding chunked document choosing-the-right-oil-for-your-car_pdf-3.json
# Success: Embedding chunked document bike-and-scooter_pdf-1.json
# Success: Embedding chunked document mobil-1-turbo-diesel-pickup-5w40_pdf-3.json
# Success: Embedding chunked document suzuki_pdf-2.json
# Success: Embedding chunked document toyota_pdf-2.json
# Success: Embedding chunked document mobil-super_pdf-2.json

# %%
print_warning_message("Create Azure AI Search index", ">>>[STEP5] ")

# Create a search index
index_client = SearchIndexClient(endpoint=service_endpoint, credential=credential)
fields = [
    SimpleField(name="id", type=SearchFieldDataType.String, key=True, sortable=True, filterable=True, facetable=True),
    SearchableField(name="content", type=SearchFieldDataType.String),
    SearchableField(name="category", type=SearchFieldDataType.String, filterable=True),
    SearchableField(name="sourcepage", type=SearchFieldDataType.String),
    SearchableField(name="sourcefile", type=SearchFieldDataType.String),
    SearchField(name="contentVector", type=SearchFieldDataType.Collection(SearchFieldDataType.Single),
                searchable=True, vector_search_dimensions=1536, vector_search_configuration="my-vector-config"),
]

vector_search = VectorSearch(
    algorithm_configurations=[
        HnswVectorSearchAlgorithmConfiguration(
            name="my-vector-config",
            kind="hnsw",
        )
    ]
)

semantic_config = SemanticConfiguration(
    name="my-semantic-config",
    prioritized_fields=PrioritizedFields(
        prioritized_content_fields=[SemanticField(field_name="content")]
    )
)

# Create the semantic settings with the configuration
semantic_settings = SemanticSettings(configurations=[semantic_config])

# Create the search index with the semantic settings
index = SearchIndex(name=index_name, fields=fields, vector_search=vector_search,
                    semantic_settings=semantic_settings)
result = index_client.create_or_update_index(index)
print_success_message(f'Index name: "{result.name}" is created')
# Out:
# >>>[STEP5] Create Azure AI Search index
# Success: Index name: "bootcathon-thanawat-index" is created

# %%
print_warning_message("Upload embedded chunk documents to Azure AI Index", ">>>[STEP6] ")

search_client = SearchClient(endpoint=service_endpoint, index_name=index_name, credential=credential)
        
for file in Path().glob("data/chunked_document_vector/*.json"):
    input_data = json.loads(file.read_text())
    result = search_client.upload_documents(input_data)
    print_success_message(f"Uploaded embedded chunk: {file.name} to {index_name} index.")
# Out:
# >>>[STEP6] Upload embedded chunk documents to Azure AI Index
# Success: Uploaded embedded chunk: mobil-super-moto-20w40_pdf-0.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: choosing-the-right-oil-for-your-car_pdf-0.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: mobil-1_pdf-0.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: suzuki_pdf-1.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: mobil-1-turbo-diesel-pickup-5w40_pdf-0.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: mobil-super_pdf-1.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: toyota_pdf-1.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: mobil-super-moto-scooter-gear-oil_pdf-1.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: mazda_pdf-1.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: mobil-super-moto-scooter-10w40_pdf-1.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: product-oem-bmw_pdf-1.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: subaru_pdf-1.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: recommended-for-your-car_pdf-0.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: isuzu_pdf-0.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: mobil-1-esp-0w-30_pdf-1.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: choose-the-right-engine-oil_pdf-2.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: mobil-super-friction-fighter-10w-40_pdf-1.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: mobil-super-friction-fighter-10w-40_pdf-0.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: mobil-1-esp-0w-30_pdf-0.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: isuzu_pdf-1.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: recommended-for-your-car_pdf-1.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: subaru_pdf-0.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: product-oem-bmw_pdf-0.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: mobil-super-moto-scooter-10w40_pdf-0.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: mazda_pdf-0.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: mobil-super-moto-scooter-gear-oil_pdf-0.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: mobil-super_pdf-0.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: toyota_pdf-0.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: suzuki_pdf-0.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: mobil-1-turbo-diesel-pickup-5w40_pdf-1.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: mobil-1_pdf-1.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: choosing-the-right-oil-for-your-car_pdf-1.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: tips-all-drivers-should-know_pdf-2.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: mobil-super-moto-20w40_pdf-1.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: mobil-super-all-in-one-protection-0w-20_pdf-0.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: honda_pdf-1.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: changing-motorbike-engine-oil_pdf-1.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: mobil-1-racing-4t-10w40_pdf-2.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: mobil-super-all-in-one-protection-5w-30_pdf-2.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: mobil-super-all-in-one-protection-5w-40_pdf-1.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: mobil-super-everyday-protection-20w-50_pdf-0.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: time-to-add-car-care-to-your-calendar_pdf-1.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: bike-and-scooter-products_pdf-0.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: bmw_pdf-0.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: car_pdf-1.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: where-to-buy_pdf-1.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: ford_pdf-1.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: nissan_pdf-2.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: ford_pdf-0.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: car_pdf-0.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: where-to-buy_pdf-0.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: bmw_pdf-1.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: bike-and-scooter-products_pdf-1.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: time-to-add-car-care-to-your-calendar_pdf-0.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: mobil-super-all-in-one-protection-5w-40_pdf-0.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: mobil-super-everyday-protection-20w-50_pdf-1.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: mitsubishi_pdf-2.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: mobil-super-moto_pdf-2.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: changing-motorbike-engine-oil_pdf-0.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: honda_pdf-0.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: mobil-super-all-in-one-protection-0w-20_pdf-1.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: mitsubishi_pdf-1.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: why-mobil_pdf-0.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: mobil-super-moto_pdf-1.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: mobil-1-racing-4t-10w40_pdf-0.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: mobil-super-moto-10w30_pdf-1.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: mobil-super-all-in-one-protection-0w-20_pdf-2.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: nissan_pdf-0.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: bmw_pdf-2.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: bike-and-scooter-products_pdf-2.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: mobil-super-everyday-protection-20w-50_pdf-2.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: mobil-super-all-in-one-protection-5w-30_pdf-0.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: mobil-super-all-in-one-protection-5w-30_pdf-1.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: ford_pdf-2.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: nissan_pdf-1.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: honda_pdf-2.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: changing-motorbike-engine-oil_pdf-2.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: mobil-1-racing-4t-10w40_pdf-1.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: mobil-super-moto-10w30_pdf-0.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: mobil-super-moto_pdf-0.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: why-mobil_pdf-1.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: mitsubishi_pdf-0.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: toyota_pdf-3.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: mobil-1-turbo-diesel-pickup-5w40_pdf-2.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: mobil-1_pdf-2.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: choosing-the-right-oil-for-your-car_pdf-2.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: bike-and-scooter_pdf-0.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: tips-all-drivers-should-know_pdf-1.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: mobil-super-moto-20w-50_pdf-0.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: benchmarks-to-change-motorcyle-engine-oils_pdf-0.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: choose-the-right-engine-oil_pdf-0.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: isuzu_pdf-2.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: mobil-super-moto-10w-40_pdf-0.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: mobil-super-moto-10w-40_pdf-1.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: mazda_pdf-2.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: product-oem-bmw_pdf-2.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: subaru_pdf-2.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: mobil-1-esp-0w-30_pdf-2.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: choose-the-right-engine-oil_pdf-1.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: benchmarks-to-change-motorcyle-engine-oils_pdf-1.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: mobil-super-moto-20w-50_pdf-1.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: tips-all-drivers-should-know_pdf-0.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: choosing-the-right-oil-for-your-car_pdf-3.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: bike-and-scooter_pdf-1.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: mobil-1-turbo-diesel-pickup-5w40_pdf-3.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: suzuki_pdf-2.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: toyota_pdf-2.json to bootcathon-thanawat-index index.
# Success: Uploaded embedded chunk: mobil-super_pdf-2.json to bootcathon-thanawat-index index.
